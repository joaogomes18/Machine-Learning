# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pnd
import seaborn as sns
from math import pi

# %%
relevant_features = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "diagnosis"]
data = pnd.read_csv("processed.cleveland.csv", names=relevant_features)

# %%
data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  diagnosis
# 0    3.0  0.0  6.0          0
# 1    2.0  3.0  3.0          2
# 2    2.0  2.0  7.0          1
# 3    3.0  0.0  3.0          0
# 4    1.0  0.0  3.0          0

# %%
#ignoring null values and transformation of all values from (float and string) to (float)
data.drop(data[data["ca"] == '?'].index, inplace=True)
data.drop(data[data["thal"] == '?'].index, inplace=True)
data = data.astype('float64') 
data0 = data.drop(data[data["diagnosis"] != 0].index)
data1 = data.drop(data[data["diagnosis"] != 1].index)
data2 = data.drop(data[data["diagnosis"] != 2].index)
data3 = data.drop(data[data["diagnosis"] != 3].index)
data4 = data.drop(data[data["diagnosis"] != 4].index)
dataD = data.drop(data[data["diagnosis"] == 0].index)

#print(len(data0)) 160
#print(len(data1)) 54
#print(len(data2)) 35
#print(len(data3)) 35
#print(len(data4)) 13
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    3.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    1.602694    0.676768
# ...

# %%
data_n = data.values

X = data_n[:,:-1]
y = data_n[:,-1]

#X.shape = (297,13)
y = y.reshape(X.shape[0],1)
#y.shape = (297,1)

m = X.shape[0]

# %%
diag0 = (y==0)
diag1 = (y==1)
diag2 = (y==2)
diag3 = (y==3)
diag4 = (y==4)

plt.scatter(X[diag0[:,0],0],X[diag0[:,0],1],c='#1f77b4',marker="+")
plt.scatter(X[diag1[:,0],0],X[diag1[:,0],1],c="#ff7f0e",marker="o")
plt.scatter(X[diag2[:,0],0],X[diag2[:,0],1],c="#2ca02c",marker="x")
plt.scatter(X[diag3[:,0],0],X[diag3[:,0],1],c="#d62728",marker="d")
plt.scatter(X[diag4[:,0],0],X[diag4[:,0],1])
plt.xticks(np.arange(28, 78, 10))
plt.yticks(np.arange(0, 2, 1))
plt.xlabel("Age in years")
plt.ylabel("Sex (0 = female; 1 = male)")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3", "Diagnosis 4"])

# %%
plt.scatter(X[diag0[:,0],2],X[diag0[:,0],3],c='#1f77b4',marker="+")
plt.scatter(X[diag1[:,0],2],X[diag1[:,0],3],c="#ff7f0e",marker="o")
plt.scatter(X[diag2[:,0],2],X[diag2[:,0],3],c="#2ca02c",marker="x")
plt.scatter(X[diag3[:,0],2],X[diag3[:,0],3],c="#d62728",marker="d")
plt.scatter(X[diag4[:,0],2],X[diag4[:,0],3])
plt.xticks(np.arange(1, 5, 1))
plt.yticks(np.arange(93, 201, 15))
plt.xlabel("Chest Pain Type (1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic)")
plt.ylabel("Resting Blood Pressure (in mm Hg on admission to the hospital)")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3"])

# %%
plt.scatter(X[diag0[:,0],4],X[diag0[:,0],5],c='#1f77b4',marker="+")
plt.scatter(X[diag1[:,0],4],X[diag1[:,0],5],c="#ff7f0e",marker="o")
plt.scatter(X[diag2[:,0],4],X[diag2[:,0],5],c="#2ca02c",marker="x")
plt.scatter(X[diag3[:,0],4],X[diag3[:,0],5],c="#d62728",marker="d")
plt.xticks(np.arange(125, 565, 50))
plt.yticks(np.arange(0, 1, 1))
plt.xlabel("Serum Cholestoral in mg/dl")
plt.ylabel("Fasting Blood Sugar > 120 mg/dl  (1 = true; 0 = false)")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3"])

# %%
plt.scatter(X[diag0[:,0],6],X[diag0[:,0],7],c='#1f77b4',marker="+")
plt.scatter(X[diag1[:,0],6],X[diag1[:,0],7],c="#ff7f0e",marker="o")
plt.scatter(X[diag2[:,0],6],X[diag2[:,0],7],c="#2ca02c",marker="x")
plt.scatter(X[diag3[:,0],6],X[diag3[:,0],7],c="#d62728",marker="d")
plt.xticks(np.arange(0, 3, 1))
plt.yticks(np.arange(70, 203, 20))
plt.xlabel("Resting Electrocardiographic Results (0: normal, 1: having ST-T wave abnormality, 2: showing probable or definite left ventricular hypertrophy by Estes' criteria)")
plt.ylabel("maximum heart rate achieved")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3"])

# %%
plt.scatter(X[diag0[:,0],8],X[diag0[:,0],9],c='#1f77b4',marker="+")
plt.scatter(X[diag1[:,0],8],X[diag1[:,0],9],c="#ff7f0e",marker="o")
plt.scatter(X[diag2[:,0],8],X[diag2[:,0],9],c="#2ca02c",marker="x")
plt.scatter(X[diag3[:,0],8],X[diag3[:,0],9],c="#d62728",marker="d")
plt.xticks(np.arange(0, 2, 1))
plt.yticks(np.arange(0, 7, 1))
plt.xlabel("Exercise Induced Angina (1 = yes; 0 = no)")
plt.ylabel("ST Depression Induced by Exercise Relative to Rest")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3"])

# %%
plt.scatter(X[diag0[:,0],10],X[diag0[:,0],11],c='#1f77b4',marker="+")
plt.scatter(X[diag1[:,0],10],X[diag1[:,0],11],c="#ff7f0e",marker="o")
plt.scatter(X[diag2[:,0],10],X[diag2[:,0],11],c="#2ca02c",marker="x")
plt.scatter(X[diag3[:,0],10],X[diag3[:,0],11],c="#d62728",marker="d")
plt.xticks(np.arange(1, 4, 1))
plt.yticks(np.arange(0, 4, 1))
plt.xlabel("The Slope of the Peak Exercise ST Segment (1: upsloping, 2: flat, 3: downsloping)")
plt.ylabel("Number of Major Vessels (0-3) Colored by Flourosopy")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3"])

# %%
plt.hist(x=X[diag0[:,0],12])
plt.hist(x=X[diag1[:,0],12])
plt.hist(x=X[diag2[:,0],12])
plt.hist(x=X[diag3[:,0],12])
plt.xticks(np.arange(3, 8, 1))
plt.xlabel("3 = normal; 6 = fixed defect; 7 = reversable defect")
plt.ylabel("Count")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3"])

# %%
plt.hist(x=y[diag0[:]])
plt.hist(x=y[diag1[:]])
plt.hist(x=y[diag2[:]])
plt.hist(x=y[diag3[:]])
plt.xticks(np.arange(0, 4, 1))
plt.xlabel("3 = normal; 6 = fixed defect; 7 = reversable defect")
plt.ylabel("Count")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3"])

# %%
sns.set(style='whitegrid', context='notebook')
sns.pairplot(data0[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]], height=2)
plt.title("Diagnosis 0")
#plt.show()
plt.savefig("diagnosis0_mult.png")

# %%
cols = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]
cm = np.corrcoef(data0[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':8},
                 yticklabels=cols, xticklabels=cols)
plt.title("Diagnosis 0")
#plt.show()
plt.savefig("diagnosis0_corr.png")

# %%
sns.set(style='whitegrid', context='notebook')
sns.pairplot(data1[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]], height=2)
plt.title("Diagnosis 1")
#plt.show()
plt.savefig("diagnosis1_mult.png")

# %%
cols = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]
cm = np.corrcoef(data1[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':8},
                 yticklabels=cols, xticklabels=cols)
plt.title("Diagnosis 1")
#plt.show()
plt.savefig("diagnosis1_corr.png")

# %%
sns.set(style='whitegrid', context='notebook')
sns.pairplot(data2[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]], height=2)
plt.title("Diagnosis 2")
#plt.show()
plt.savefig("diagnosis2_mult.png")

# %%
cols = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]
cm = np.corrcoef(data2[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':8},
                 yticklabels=cols, xticklabels=cols)
plt.title("Diagnosis 2")
#plt.show()
plt.savefig("diagnosis2_corr.png")

# %%
sns.set(style='whitegrid', context='notebook')
sns.pairplot(data3[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]], height=2)
plt.title("Diagnosis 3")
#plt.show()
plt.savefig("diagnosis3_mult.png")

# %%
cols = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]
cm = np.corrcoef(data3[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':8},
                 yticklabels=cols, xticklabels=cols)
plt.title("Diagnosis 3")
#plt.show()
plt.savefig("diagnosis3_corr.png")

# %%
sns.set(style='whitegrid', context='notebook')
sns.pairplot(data4[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]], height=2)
plt.title("Diagnosis 4")
#plt.show()
plt.savefig("diagnosis4_mult.png")

# %%
cols = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]
cm = np.corrcoef(data4[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':8},
                 yticklabels=cols, xticklabels=cols)
plt.title("Diagnosis 4")
#plt.show()
plt.savefig("diagnosis4_corr.png")

# %%
sns.set(style='whitegrid', context='notebook')
sns.pairplot(dataD[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "diagnosis"]], height=2)
plt.title("Diagnosis diferent than 0")
#plt.show()
plt.savefig("diagnosisD_mult.png")

# %%
cols = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal"]
cm = np.corrcoef(dataD[["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal","diagnosis"]].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':8},
                 yticklabels=cols, xticklabels=cols)
plt.title("Diagnosis diferent than 0")
#plt.show()
plt.savefig("diagnosisD_corr.png")

# %%
def featureNormalization(X):
    """
    Take in numpy array of X values and return normalize X values,
    the mean and standard deviation of each feature
    """
    mean=np.mean(X,axis=0)
    std=np.std(X,axis=0)
    
    X_norm = (X-mean)/std
    
#     X_norm = np.absolute(X_norm)
    
    return X_norm , mean , std

categories = relevant_features[:-1]
N = len(categories)

data_norm, mean, std = featureNormalization(data)

# print(data_norm)

valuesData = data_norm.values.mean(axis=0)
valuesData0 = data_norm.drop(data_norm[data["diagnosis"] != 0].index).values.mean(axis=0)
valuesData1 = data_norm.drop(data_norm[data["diagnosis"] != 1].index).values.mean(axis=0)
valuesData2 = data_norm.drop(data_norm[data["diagnosis"] != 2].index).values.mean(axis=0)
valuesData3 = data_norm.drop(data_norm[data["diagnosis"] != 3].index).values.mean(axis=0)
valuesData4 = data_norm.drop(data_norm[data["diagnosis"] != 4].index).values.mean(axis=0)
valuesDataD = data_norm.drop(data_norm[data["diagnosis"] == 0].index).values.mean(axis=0)

valuesData = valuesData[0:-1]
valuesData0 = valuesData0[0:-1]
valuesData1 = valuesData1[0:-1]
valuesData2 = valuesData2[0:-1]
valuesData3 = valuesData3[0:-1]
valuesData4 = valuesData4[0:-1]
valuesDataD = valuesDataD[0:-1]

valuesData = np.append(valuesData, valuesData[:1])
valuesData0 = np.append(valuesData0, valuesData0[:1])
valuesData1 = np.append(valuesData1, valuesData1[:1])
valuesData2 = np.append(valuesData2, valuesData2[:1])
valuesData3 = np.append(valuesData3, valuesData3[:1])
valuesData4 = np.append(valuesData4, valuesData4[:1])
valuesDataD = np.append(valuesDataD, valuesDataD[:1])

# valuesData, mean, std = featureNormalization(valuesData)
# valuesData0, mean, std = featureNormalization(valuesData0)
# valuesData1, mean, std = featureNormalization(valuesData1)
# valuesData2, mean, std = featureNormalization(valuesData2)
# valuesData3, mean, std = featureNormalization(valuesData3)
# valuesData4, mean, std = featureNormalization(valuesData4)
# valuesDataD, mean, std = featureNormalization(valuesDataD)

angles = []

for n in range(N):
    angles.append(n/13.0*2*pi)

# angles = [n / 13.0 * 2 * pi for n in range(N)]
angles += angles[:1]

print(valuesData)
print(valuesData0)
print(valuesData1)
print(valuesData2)
print(valuesData3)
print(valuesData4)
print(valuesDataD)
# Out:
# [-1.18124739e-16 -4.18669962e-17 -2.69144976e-17  4.90441956e-16
#  -1.82420484e-16 -4.78479957e-17  4.78479957e-17  4.78479957e-16
#  -2.99049973e-17 -1.91391983e-16 -4.18669962e-17 -2.99049973e-17
#  -2.03353982e-16 -1.18124739e-16]
# [-0.21012122 -0.25767575 -0.37841197 -0.14203012 -0.07429051 -0.00293039
#  -0.15392391  0.39217394 -0.38989615 -0.39239139 -0.30818292 -0.42860593
#  -0.48731949 -0.21012122]
# [ 0.11832697  0.33474901  0.18176708  0.08933548  0.0346365  -0.2535682
#   0.15254676 -0.15796445  0.25128536 -0.028633    0.04364618  0.06824649
#   0.30184277  0.11832697]
# [ 0.40488322  0.26347987  0.60692227  0.1510091   0.2602      0.23812173
#  -0.05414199 -0.63744425  0.58298202  0.64192456  0.45859661  0.61914449
#   0.6706402   0.40488322]
# [ 0.1613719   0.26347987  0.63658426  0.21223516 -0.01720335  0.23812173
#   0.29104952 -0.76593698  0.70482978  0.77936296  0.59748498  0.83250458
#   0.8035057   0.1613719 ]
# ...

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.subplot(polar="True")

# plt.polar(angles, valuesData, marker=".", color = "orange")
# plt.fill(angles, valuesData, alpha = 0.3)
plt.polar(angles, valuesData0, marker=".", color = "blue")
plt.fill(angles, valuesData0, alpha = 0.3)
plt.polar(angles, valuesData1, marker=".", color = "red")
plt.fill(angles, valuesData1, alpha = 0.3)
plt.polar(angles, valuesData2, marker=".", color = "green")
plt.fill(angles, valuesData2, alpha = 0.3)
plt.polar(angles, valuesData3, marker=".", color = "yellow")
plt.fill(angles, valuesData3, alpha = 0.3)
plt.polar(angles, valuesData4, marker=".", color = "brown")
plt.fill(angles, valuesData4,alpha = 0.3)
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([-1, -0.5, 0, 0.5, 1], color="grey", size = 10, alpha = 1)
plt.ylim(-1.5,1.5)
plt.title("Comparison between all diagnosis")
plt.legend(["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3", "Diagnosis 4"])
plt.savefig("Comparison between all diagnosis on a Radar Chart")

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.subplot(polar="True")

plt.polar(angles, valuesData, marker=".", color = "orange")
plt.fill(angles, valuesData, alpha = 0.3)
plt.polar(angles, valuesData0, marker=".", color = "blue")
plt.fill(angles, valuesData0, alpha = 0.3)
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([-1, -0.5, 0, 0.5, 1], color="grey", size = 10, alpha = 1)
plt.ylim(-1.5,1.5)
plt.title("Comparison between all diagnosis vs diagnosis 0")
plt.legend(["All diagnosis", "Diagnosis 0"])
plt.savefig("Comparison between all diagnosis vs diagnosis 0 a Radar Chart")

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.subplot(polar="True")

plt.polar(angles, valuesData, marker=".", color = "orange")
plt.fill(angles, valuesData, alpha = 0.3)
plt.polar(angles, valuesData1, marker=".", color = "red")
plt.fill(angles, valuesData1, alpha = 0.3)
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([-1, -0.5, 0, 0.5, 1], color="grey", size = 10, alpha = 1)
plt.ylim(-1.5,1.5)
plt.title("Comparison between all diagnosis vs diagnosis 1")
plt.legend(["All diagnosis", "Diagnosis 1"])
plt.savefig("Comparison between all diagnosis vs diagnosis 1 a Radar Chart")

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.subplot(polar="True")

plt.polar(angles, valuesData, marker=".", color = "orange")
plt.fill(angles, valuesData, alpha = 0.3)
plt.polar(angles, valuesData2, marker=".", color = "green")
plt.fill(angles, valuesData2, alpha = 0.3)
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([-1, -0.5, 0, 0.5, 1], color="grey", size = 10, alpha = 1)
plt.ylim(-1.5,1.5)
plt.title("Comparison between all diagnosis vs diagnosis 2")
plt.legend(["All diagnosis", "Diagnosis 2"])
plt.savefig("Comparison between all diagnosis vs diagnosis 2 a Radar Chart")

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.subplot(polar="True")

plt.polar(angles, valuesData, marker=".", color = "orange")
plt.fill(angles, valuesData, alpha = 0.3)
plt.polar(angles, valuesData3, marker=".", color = "yellow")
plt.fill(angles, valuesData3, alpha = 0.3)
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([-1, -0.5, 0, 0.5, 1], color="grey", size = 10, alpha = 1)
plt.ylim(-1.5,1.5)
plt.title("Comparison between all diagnosis vs diagnosis 3")
plt.legend(["All diagnosis", "Diagnosis 3"])
plt.savefig("Comparison between all diagnosis vs diagnosis 3 a Radar Chart")

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.subplot(polar="True")

plt.polar(angles, valuesData, marker=".", color = "orange")
plt.fill(angles, valuesData, alpha = 0.3)
plt.polar(angles, valuesData4, marker=".", color = "brown")
plt.fill(angles, valuesData4,alpha = 0.3)
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([-1, -0.5, 0, 0.5, 1], color="grey", size = 10, alpha = 1)
plt.ylim(-1.5,1.5)
plt.title("Comparison between all diagnosis vs diagnosis 4")
plt.legend(["All diagnosis", "Diagnosis 4"])
plt.savefig("Comparison between all diagnosis vs diagnosis 4 a Radar Chart")

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.subplot(polar="True")

plt.polar(angles, valuesData0, marker=".", color = "blue")
plt.fill(angles, valuesData0, alpha = 0.3)
plt.polar(angles, valuesDataD, marker=".", color = "black")
plt.fill(angles, valuesDataD,alpha = 0.3)
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([-1, -0.5, 0, 0.5, 1], color="grey", size = 10, alpha = 1)
plt.ylim(-1.5,1.5)
plt.title("Comparison between diagnosis 0 vs diagnosis with disease")
plt.legend(["Diagnosis 0", "Diagnosis with disease"])
plt.savefig("Comparison between diagnosis 0 vs diagnosis with disease in a Radar Chart")

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.subplot(polar="True")

plt.polar(angles, valuesData, marker=".", color = "orange")
plt.fill(angles, valuesData, alpha = 0.3)
plt.polar(angles, valuesData0, marker=".", color = "blue")
plt.fill(angles, valuesData0, alpha = 0.3)
plt.polar(angles, valuesData1, marker=".", color = "red")
plt.fill(angles, valuesData1, alpha = 0.3)
plt.polar(angles, valuesData2, marker=".", color = "green")
plt.fill(angles, valuesData2, alpha = 0.3)
plt.polar(angles, valuesData3, marker=".", color = "yellow")
plt.fill(angles, valuesData3, alpha = 0.3)
plt.polar(angles, valuesData4, marker=".", color = "brown")
plt.fill(angles, valuesData4,alpha = 0.3)
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([-1, -0.5, 0, 0.5, 1], color="grey", size = 10, alpha = 1)
plt.ylim(-1.5,1.5)
plt.title("Comparison between all diagnosis including the mean of all diagnosis")
plt.legend(["All diagnosis", "Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3", "Diagnosis 4"])
plt.savefig("Comparison between all diagnosis including the mean of all diagnosis on a Radar Chart")

# %%
valuesData0 = data0[categories].values.mean(axis=0)
valuesData1 = data1[categories].values.mean(axis=0)
valuesData2 = data2[categories].values.mean(axis=0)
valuesData3 = data3[categories].values.mean(axis=0)
valuesData4 = data4[categories].values.mean(axis=0)

fig, axs = plt.subplots(2,1)
colLabels = ("age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal")

cellText = [np.around(valuesData0, 4), np.around(valuesData1, 4), np.around(valuesData2, 4), np.around(valuesData3, 4),np.around(valuesData4,4)]
rowLabels= ["Diagnosis 0", "Diagnosis 1", "Diagnosis 2", "Diagnosis 3", "Diagnosis 4"]

axs[0].axis('tight')
axs[0].axis('off')
table = axs[0].table(cellText = cellText,
                     rowLabels= rowLabels,
                     colLabels = categories,
                     loc='center')
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.box(on=None)
table.scale(3, 3)

# %%
valuesData0 = data0[categories].values.mean(axis=0)
valuesDataD = dataD[categories].values.mean(axis=0)

fig, axs = plt.subplots(2,1)
colLabels = ("age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal")

cellText = [np.around(valuesData0, 4), np.around(valuesDataD, 4)]
rowLabels= ["Diagnosis 0", "Diagnosis with disease"]

axs[0].axis('tight')
axs[0].axis('off')
table = axs[0].table(cellText = cellText,
                     rowLabels= rowLabels,
                     colLabels = categories,
                     loc='center')
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.box(on=None)
table.scale(3, 3)
